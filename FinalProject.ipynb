# %% [markdown]
# ## Prettiest Neighborhoods - Final Project
# ## _______________________________________

# %% [markdown]
# *So originally, we were going to choose water features as our metric, but it was too specific and not a lot of data sets were good enough to prove it.*
#
# **Soo..**
#
# *We decided to designate the best neighborhood as what we consider the 'prettiest' one. For our three data sets, they'll include the neighborhood with the largest acre amount, the most amount of trees, and median home values.*

# %% [markdown]
# ![tree](https://media.giphy.com/media/XbChwnACglgAF5XX3v/giphy.gif "tree")

# %% [markdown]
# ### Date Set 1 - Neighborhood with the most acres ###

# %%
import pandas as pd
import geopandas as gpd
from matplotlib import pyplot as plt

# read file in
acre = pd.read_csv("Neighborhood.csv")
acre.head(10)
# Out:
#    FID  Neighborhood_2010_FID_BlockG  Neighborhood_2010_STATEFP10  \
# 0   26                            54                           42
# 1   43                           102                           42
# 2   70                           221                           42
# 3   34                            74                           42
# 4   20                            34                           42
# 5   42                            97                           42
# 6   66                           203                           42
# 7   11                            12                           42
# 8   38                            84                           42
# 9   24                            45                           42
#
#    Neighborhood_2010_COUNTYFP10  Neighborhood_2010_TRACTCE10  \
# 0                             3                       141400
# 1                             3                       191700
# 2                             3                       562900
# 3                             3                       290400
# 4                             3                       562900
# 5                             3                       191600
# 6                             3                       140100
# 7                             3                       260700
# 8                             3                       110200
# 9                             3                       180700
#
#    Neighborhood_2010_BLKGRPCE10  Neighborhood_2010_GEOID10  \
# 0                             3               420031414003
# 1                             1               420031917001
# 2                             2               420035629002
# 3                             3               420032904003
# 4                             1               420035629001
# 5                             3               420031916003
# 6                             3               420031401003
# 7                             2               420032607002
# 8                             1               420031102001
# 9                             2               420031807002
#
#   Neighborhood_2010_NAMELSAD10 Neighborhood_2010_MTFCC10  \
# 0                Block Group 3                     G5030
# 1                Block Group 1                     G5030
# 2                Block Group 2                     G5030
# 3                Block Group 3                     G5030
# 4                Block Group 1                     G5030
# 5                Block Group 3                     G5030
# 6                Block Group 3                     G5030
# 7                Block Group 2                     G5030
# 8                Block Group 1                     G5030
# 9                Block Group 2                     G5030
#
#   Neighborhood_2010_FUNCSTAT10  ...  SNAP_All_csv_Commute_to_Work__C  \
# 0                            S  ...                             8.7%
# 1                            S  ...                             9.7%
# 2                            S  ...                            18.1%
# 3                            S  ...                            10.3%
# 4                            S  ...                             9.1%
# 5                            S  ...                            15.3%
# 6                            S  ...                             4.5%
# 7                            S  ...                            14.1%
# 8                            S  ...                            12.1%
# 9                            S  ...                             8.6%
#
#    SNAP_All_csv_Commute_to_Work__P  SNAP_All_csv_Commute_to_Work__T  \
# 0                            22.7%                             0.0%
# 1                            12.0%                             0.4%
# 2                             0.0%                             0.0%
# 3                            19.6%                             0.0%
# 4                            25.9%                             0.0%
# 5                            21.2%                             0.0%
# 6                            11.1%                             0.0%
# 7                            13.1%                             0.0%
# 8                            24.0%                             0.0%
# 9                            16.5%                             0.0%
#
#    SNAP_All_csv_Commute_to_Work__M  SNAP_All_csv_Commute_to_Work__B  \
# 0                             0.2%                             2.5%
# 1                             0.8%                             0.2%
# 2                             0.0%                             0.0%
# 3                             0.3%                             0.0%
# 4                             0.0%                             0.4%
# 5                             0.0%                             0.6%
# 6                             0.2%                             1.6%
# 7                             0.0%                             0.0%
# 8                             0.0%                             1.9%
# 9                             0.3%                             0.5%
#
#    SNAP_All_csv_Commute_to_Work__W  SNAP_All_csv_Commute_to_Work__O  \
# 0                             6.8%                             0.3%
# 1                             2.8%                             0.6%
# 2                             0.0%                             0.0%
# 3                             4.7%                             0.0%
# 4                             3.3%                             0.0%
# 5                             5.3%                             0.0%
# 6                            26.1%                             0.0%
# 7                             3.7%                             0.0%
# 8                             5.1%                             1.0%
# 9                             5.9%                             0.2%
#
#    SNAP_All_csv_Work_at_Home__2010  SHAPE_Length    SHAPE_Area
# 0                             4.8%  50179.666766  7.447239e+07
# 1                             0.5%  37396.667331  5.798882e+07
# 2                             0.0%  56370.853075  4.877996e+07
# 3                             3.1%  40393.927039  4.663720e+07
# 4                             0.8%  42027.889438  4.413393e+07
# 5                             2.6%  32742.447523  4.070408e+07
# 6                             9.0%  30347.887992  3.407739e+07
# 7                             1.7%  30830.126843  3.373206e+07
# 8                             2.4%  23261.798557  3.241981e+07
# 9                             3.0%  34003.524912  3.176526e+07
#
# [10 rows x 192 columns]

# %% [markdown]
# **As you can see, we can't find the data needed for our specific data set. So we'll have to filter according to the neighborhood column and acres column, to obtain the correct data**

# %%
acre[['Neighborhood_2010_HOOD', 'Neighborhood_2010_ACRES']]
# Out:
#    Neighborhood_2010_HOOD  Neighborhood_2010_ACRES
# 0     Squirrel Hill South                 1717.485
# 1               Brookline                 1338.669
# 2                    Hays                 1125.478
# 3                 Carrick                 1075.670
# 4               Hazelwood                 1017.805
# ..                    ...                      ...
# 85         Allegheny West                   90.841
# 86         Chartiers City                   84.954
# 87      Arlington Heights                   84.592
# 88             Friendship                   68.297
# 89             Mt. Oliver                   66.226
#
# [90 rows x 2 columns]

# %% [markdown]
# *Here we have 90 rows with many neighborhoods displayed. However, now I want to find the min, std, and max acres in the pittsburgh area.*

# %%
acre[['Neighborhood_2010_HOOD', 'Neighborhood_2010_ACRES']].describe()
# Out:
#        Neighborhood_2010_ACRES
# count                90.000000
# mean                377.121456
# std                 296.369162
# min                  66.226000
# 25%                 179.700750
# 50%                 277.143500
# 75%                 493.914750
# max                1717.485000

# %% [markdown]
# From the data shown, we can see that there are about 90 neighborhoods recorded. The average neighborhood has about 377.12 acres while the min has 66.22 acres, following the max of 1717.48 which is insane. While the standard deviation illustrates that it's on the lower side, but 296.36 acres is still a large number.

# %% [markdown]
# Now let's draw a bar graph to give a better visual

# %%
graph = acre.plot.barh(x="Neighborhood_2010_HOOD", y="Neighborhood_2010_ACRES", figsize=(15,acre.shape[0] * 0.3), legend=None)
graph.set_xlabel("Acres")
# Out:
# Text(0.5, 0, 'Acres')

# %% [markdown]
# We are only interested in the neighborhoods with the most amount of acres, so let's cut down the bar graph

# %%
graph = acre[:15].plot.barh(x="Neighborhood_2010_HOOD",y="Neighborhood_2010_ACRES",figsize=(20,acre.shape[0] * 0.1), legend=None)
graph.set_xlabel("Acres")
# Out:
# Text(0.5, 0, 'Acres')

# %%
graph = acre[:5].plot.barh(x="Neighborhood_2010_HOOD",y="Neighborhood_2010_ACRES",figsize=(20,acre.shape[0] * 0.1), legend=None)
graph.set_xlabel("Acres")
# Out:
# Text(0.5, 0, 'Acres')

# %% [markdown]
# *As you can see, the neighborhood with the most amount of acres are:
# 1. Squirrel Hill South
# 2. Brookline
# 3. Hays
# 4. Carrick
# 5. Hazelwood

# %% [markdown]
# ## Data Set 2 - Home Value

# %% [markdown]
# ![home](https://media.giphy.com/media/kd9iaS9bRfjRPVy9dM/giphy.gif "home")

# %%
import pandas as pd
import geopandas as gpd
from matplotlib import pyplot as plt

# read file in
price = pd.read_csv("Neighborhood.csv")

# %%
sortedprice = price[['SNAP_All_csv_Neighborhood', 'SNAP_All_csv_Median_Home_Value_']].sort_values(by="SNAP_All_csv_Median_Home_Value_", ascending = False)

# %%
# drops the naN values but doesn't apply it to the graph: 87 rows x 2 columns instead of 90 rows x 2 columns

sortedprice = sortedprice[['SNAP_All_csv_Neighborhood', 'SNAP_All_csv_Median_Home_Value_']].dropna()

# %%
#get rid of the commas and dollars signs so data can be calculated
dollar = sortedprice.columns
sortedprice[dollar] = sortedprice[dollar].replace({'\$':''}, regex = True)
sortedprice[dollar] = sortedprice[dollar].replace({'\,':'.'}, regex = True)
# drops naN value and converts into float
sortedprice['SNAP_All_csv_Median_Home_Value_'].astype(float).dropna()
# Out:
# 37     99.900
# 80     90.900
# 47     87.200
# 59     86.500
# 70     83.200
#        ...
# 55    159.700
# 57    153.560
# 25    134.633
# 49    115.600
# 68    113.000
# Name: SNAP_All_csv_Median_Home_Value_, Length: 87, dtype: float64

# %%
#Median Home Value is now readable for python
sortedprice['SNAP_All_csv_Median_Home_Value_']=sortedprice['SNAP_All_csv_Median_Home_Value_'].astype(float)
sortedprice[['SNAP_All_csv_Neighborhood', 'SNAP_All_csv_Median_Home_Value_']].describe()
# Out:
#        SNAP_All_csv_Median_Home_Value_
# count                        87.000000
# mean                         64.431805
# std                          42.640177
# min                          17.200000
# 25%                          39.300000
# 50%                          53.233000
# 75%                          69.516500
# max                         254.667000

# %% [markdown]
# There are about 87 neighborhoods recorded here. The median home value max is 254k while the min is 17k. This data was taken from 2010 so the prices of homes don't fit the market today.

# %%
#let's get a better visual with a graph
sortedprice['SNAP_All_csv_Median_Home_Value_']=sortedprice['SNAP_All_csv_Median_Home_Value_'].astype(float)
graph = sortedprice.plot.barh(x="SNAP_All_csv_Neighborhood", y="SNAP_All_csv_Median_Home_Value_", figsize=(15,price.shape[0] * 0.3), legend=None)
graph.set_xlabel("Median Home Value")

###IMPORTANT: TA Julianne says that Jupyter Hub is glitching the graph so please refer to to anc374 (Alex)'s notebook to see the final material of data set 2.###
# Out:
# Text(0.5, 0, 'Median Home Value')

# %%
# Out:
# Text(0.5, 0, 'Median Home Value')

# %%
#let's shorten the graph to the higher median values 
graph = sortedprice[:15].plot.barh(x="SNAP_All_csv_Neighborhood",y="SNAP_All_csv_Median_Home_Value_",figsize=(15,sortedprice.shape[0] * 0.3), legend=None)
graph.set_xlabel("Median Home Value")
# Out:
# Text(0.5, 0, 'Median Home Value')

# %%
#final graph presentation 
graph = sortedprice[:5].plot.barh(x="SNAP_All_csv_Neighborhood", y="SNAP_All_csv_Median_Home_Value_", figsize=(15,sortedprice.shape[0] * 0.3), legend=None)
graph.set_xlabel("Median Home Value")
# Out:
# Text(0.5, 0, 'Median Home Value')

# %% [markdown]
# As you can see the homes with the highest median value are:
#
# - Squirrel Hill South
# - North Oakland
# - Strip District
# - Point Breeze
# - Allegheny West

# %% [markdown]
# ## Data Set 3 - Trees

# %%
import pandas as pd
import geopandas as gpd
from matplotlib import pyplot as plt
from math import isnan
# %matplotlib inline

# %%
data = pd.read_csv("https://data.wprdc.org/datastore/dump/1515a93c-73e3-4425-9b35-1cd11b2196da", low_memory = False)
data.head(10)
# Out:
#            id address_number         street               common_name  \
# 0   754166088           7428  MONTICELLO ST                     Stump
# 1  1946899269            220     BALVER AVE        Linden: Littleleaf
# 2  1431517397           2822      SIDNEY ST                Maple: Red
# 3   994063598            608     SUISMON ST            Maple: Freeman
# 4  1591838573           1135   N NEGLEY AVE             Maple: Norway
# 5  1333224197           5550      BRYANT ST                  Oak: Pin
# 6   239290336           5503      BRYANT ST  Dogwood: Corneliancherry
# 7  1233652274           1207       KING AVE             Maple: Norway
# 8  1477030894           1201       KING AVE             Maple: Norway
# 9  1484901843           1456    WOODBINE ST             Maple: Norway
#
#      scientific_name  height  width  growth_space_length  growth_space_width  \
# 0              Stump     0.0    0.0                 10.0                 2.0
# 1      Tilia cordata     0.0    0.0                 99.0                99.0
# 2        Acer rubrum    22.0    6.0                  6.0                 3.0
# 3   Acer x freemanii    25.0   10.0                  3.0                 3.0
# 4   Acer platanoides    52.0   13.0                 99.0                99.0
# 5  Quercus palustris    45.0   18.0                 35.0                 3.0
# 6         Cornus mas     8.0    4.0                 99.0                 3.0
# 7   Acer platanoides    27.0   10.0                 30.0                 3.0
# 8   Acer platanoides    35.0   12.0                  3.0                 3.0
# 9   Acer platanoides     NaN    NaN                  NaN                 NaN
#
#       growth_space_type  ...      neighborhood  council_district  ward  \
# 0           Well or Pit  ...    Homewood North               9.0  13.0
# 1  Open or Unrestricted  ...           Oakwood               2.0  28.0
# 2           Well or Pit  ...  South Side Flats               3.0  16.0
# 3           Well or Pit  ...    East Allegheny               1.0  23.0
# 4  Open or Unrestricted  ...     Highland Park               7.0  11.0
# 5  Tree Lawn or Parkway  ...     Highland Park               7.0  11.0
# 6  Tree Lawn or Parkway  ...     Highland Park               7.0  11.0
# 7  Tree Lawn or Parkway  ...     Highland Park               7.0  11.0
# 8           Well or Pit  ...     Highland Park               7.0  11.0
# 9  Open or Unrestricted  ...   Stanton Heights               7.0  10.0
#
#           tract public_works_division  pli_division  police_zone  fire_zone  \
# 0  4.200313e+10                   2.0          13.0          5.0       3-17
# 1  4.200356e+10                   5.0          28.0          6.0       1-19
# 2  4.200316e+10                   3.0          16.0          3.0       4-24
# 3  4.200356e+10                   1.0          23.0          1.0        1-6
# 4  4.200311e+10                   2.0          11.0          5.0        3-9
# 5  4.200311e+10                   2.0          11.0          5.0        3-9
# 6  4.200311e+10                   2.0          11.0          5.0        3-9
# 7  4.200311e+10                   2.0          11.0          5.0        3-9
# 8  4.200311e+10                   2.0          11.0          5.0        3-9
# 9  4.200310e+10                   2.0          10.0          5.0        3-7
#
#     latitude  longitude
# 0  40.458169 -79.889724
# 1  40.429269 -80.067868
# 2  40.426797 -79.965035
# 3  40.455503 -79.999276
# 4  40.476667 -79.924106
# 5  40.477496 -79.924568
# 6  40.478403 -79.925985
# 7  40.478404 -79.926126
# 8  40.478314 -79.926161
# 9  40.485240 -79.936390
#
# [10 rows x 58 columns]

# %% [markdown]
# Looking at this data set, the best way to determine the best neighborhood is to see which neighborhood appears the most amount of times in the data set. The neighborhood with the highest number has the most trees, and hence is the best.

# %% [markdown]
# This data set has a lot of columns that I don't need! It will be much easier to filter out the columns that are not significant to my analysis. The code below narrows my focus to the column labeled "neighborhoods" and also ensures that I don't get any NaNs in my data.

# %%
#This code checks to see if the street is in the dictionary. If it is, then I added one to the key. If it is not, or contains a string value, which makes it NaN, then I set it to one.
data_dict = dict()
for i in range(len(data)):
    neighborhood = data.loc[i, 'neighborhood']
    if neighborhood in data_dict:
        data_dict[neighborhood] += 1
    elif isinstance(neighborhood, str):
        data_dict[neighborhood] = 1

# %%
#If a street has a value less than 300, then I removed it from the dictionary.
for neighborhood in list(data_dict.keys()):
    if data_dict[neighborhood] < 300:
        del data_dict[neighborhood]
#I then converted the dictionary back into a Series     
data_series = pd.Series(data_dict, dtype='float64')
data_series.sort_values(ascending = False)[:]
# Out:
# Squirrel Hill South          5073.0
# Highland Park                2941.0
# Squirrel Hill North          2083.0
# South Side Flats             1693.0
# Shadyside                    1558.0
# Bloomfield                   1436.0
# East Liberty                 1366.0
# Point Breeze                 1316.0
# Perry North                  1007.0
# Central Business District    1002.0
# Brighton Heights              910.0
# Mount Washington              874.0
# Allegheny Center              867.0
# Brookline                     853.0
# North Oakland                 775.0
# Carrick                       772.0
# Greenfield                    745.0
# Central Lawrenceville         713.0
# Manchester                    707.0
# Stanton Heights               700.0
# Central Northside             674.0
# Hazelwood                     652.0
# Garfield                      626.0
# Beechview                     611.0
# Crawford-Roberts              568.0
# Point Breeze North            566.0
# Lincoln-Lemington-Belmar      525.0
# Lower Lawrenceville           508.0
# Marshall-Shadeland            488.0
# Strip District                486.0
# East Hills                    483.0
# Morningside                   461.0
# Homewood South                459.0
# North Shore                   457.0
# Banksville                    437.0
# Regent Square                 434.0
# Knoxville                     432.0
# Homewood North                403.0
# Sheraden                      392.0
# East Allegheny                391.0
# Allegheny West                386.0
# Upper Lawrenceville           373.0
# Crafton Heights               368.0
# Central Oakland               368.0
# Perry South                   367.0
# Friendship                    362.0
# Middle Hill                   341.0
# Larimer                       306.0
# dtype: float64

# %% [markdown]
# Now I can see how many times each neighborhood appears in the data set! From this list, we can see that the top five neighborhoods are Squirrel Hill South, Highland Park, Squirrel Hill North, South Side Flats, and Shadyside. Let's make a bar graph to visualize the results.

# %%
data_series.sort_values(ascending = False)[:].plot.bar()
plt.title('Trees in Neighborhoods')
plt.xlabel('Neighborhoods')
plt.ylabel('Trees')
# Out:
# Text(0, 0.5, 'Trees')

# %% [markdown]
# Umm, I can't really see the graph properly, there are too many neighborhoods. Let's narrow the graph down to the top 10 neighborhoods.

# %%
data_series.sort_values(ascending = False)[:10].plot.bar()
plt.title('Trees in Neighborhoods')
plt.xlabel('Neighborhoods')
plt.ylabel('Trees')
# Out:
# Text(0, 0.5, 'Trees')

# %% [markdown]
# From this plot, we can see that Squirrel Hill South has the most amount of trees, and is hence the best neighborhood. Hence, Squirrel Hill South is the best neighborhood.

# %% [markdown]
# ## Conclusion
# As you can see, Squirrel Hill is the clear winner across all three data sets.

# %% [markdown]
# Alex: Squirrel Hill (North and South) are what we considered the prettiest (best) neighborhood as it had the most trees, largest acre amount, and highest median home value.

# %% [markdown]
# Areej: I personally think that Squirrel Hill is the best neighborhood because of all of the streets, and more trees. Also, there are more buildings there.

# %% [markdown]
# ![squireel](https://media.giphy.com/media/oKIeU1SbIGyXu/giphy.gif "squireel")
